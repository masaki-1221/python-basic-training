# %% [markdown]
# ## 文字列の結合

# %%
# 1. 文字列の結合（プラス記号）
print('こんにちは、' + '山田さん')

# %%
# 2. 文字列の繰り返し（アスタリスク）
print('Python' * 3)
print('-' * 20)

# %% [markdown]
# ## インデックス

# %%
# 3. インデックス（位置は0から数える）
text = 'Python'
print(text[0])  # P（1文字目）
print(text[1])  # y（2文字目）
print(text[2])  # t（3文字目）

# %%
# 4. マイナスのインデックス（後ろから数える）
text = 'Python'
print(text[-1])  # n（最後の文字）
print(text[-2])  # o（最後から2番目）

# %% [markdown]
# ## スライス

# %%
# 5. スライス（範囲を指定して切り出す）
text = 'Python'
print(text[0:3])  # Pyt（0番目から2番目まで）
print(text[2:5])  # tho（2番目から4番目まで）

# %%
# 6. スライスの省略
text = 'Python'
print(text[:3])   # Pyt（最初から2番目まで）
print(text[3:])   # hon（3番目から最後まで）

# %% [markdown]
# ## 文字列メソッド

# %%
# 7. upper / lower（大文字・小文字変換）
text = 'Hello World'
print(text.upper())  # HELLO WORLD
print(text.lower())  # hello world

# %%
# 8. strip（前後の空白を削除）
text = '   Hello World   '
print(text.strip())  # Hello World

# %%
# 9. replace（文字列を置換）
text = 'Hello World'
print(text.replace('World', 'Python'))  # Hello Python

# %% [markdown]
# ## f-strings

# %%
# 10. f-strings（変数を埋め込む）
name = '山田'
age = 25
print(f'私の名前は{name}です。{age}歳です。')

# %%
# 11. f-stringsなら型変換も不要（比較用）
price = 100
print('価格は' + str(price) + '円です')  # str()が必要
print(f'価格は{price}円です')             # f-stringsなら自動変換
