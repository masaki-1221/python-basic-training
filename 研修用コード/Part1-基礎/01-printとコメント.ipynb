# %%
# 1. 文字列を出力
print('Hello World')

# %%
# 2. ダブルクォーテーションでもOK
print("Hello World")

# %%
# 3. クォーテーションがないとエラー
# print(Hello World)

# %%
# 4. コメント
# シャープを付けた行は実行されない
print('この行は実行されます')
# print('この行はコメントなので実行されません')
