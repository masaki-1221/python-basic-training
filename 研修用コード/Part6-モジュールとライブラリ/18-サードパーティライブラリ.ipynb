# %% [markdown]
# ## サードパーティライブラリとは

# %%
# Pythonに最初から入っていない、外部で開発されたライブラリ
# pip install コマンドでインストールして使う

# 例：
# pip install pandas
# pip install requests
# pip install openpyxl

# %% [markdown]
# ## よく使うサードパーティライブラリ

# %%
# 1. pandas（データ分析）
# ※ pip install pandas が必要

# import pandas as pd
# 
# # CSVファイルを読み込む
# df = pd.read_csv('data.csv')
# print(df.head())  # 最初の5行を表示

# %%
# 2. openpyxl（Excel操作）
# ※ pip install openpyxl が必要

# from openpyxl import Workbook, load_workbook
# 
# # Excelファイルを読み込む
# wb = load_workbook('sample.xlsx')
# ws = wb.active
# print(ws['A1'].value)  # A1セルの値

# %%
# 3. requests（Web通信）
# ※ pip install requests が必要

# import requests
# 
# # Webページを取得
# response = requests.get('https://example.com')
# print(response.status_code)  # 200 = 成功

# %%
# 4. selenium / playwright（ブラウザ自動操作）
# ※ pip install playwright が必要

# from playwright.sync_api import sync_playwright
# 
# with sync_playwright() as p:
#     browser = p.chromium.launch()
#     page = browser.new_page()
#     page.goto('https://example.com')
#     print(page.title())
#     browser.close()

# %% [markdown]
# ## ライブラリの調べ方

# %%
# ・公式ドキュメントを確認
# ・生成AIに質問する
# ・「ライブラリ名 使い方」で検索

# 生成AIにコードを書いてもらう際は
# 「pandasを使って」のように指定すると良い

# %% [markdown]
# ## 仮想環境について

# %%
# プロジェクトごとにライブラリを分けたい場合は仮想環境を使う

# 仮想環境の作成（コマンドプロンプト）
# python -m venv .venv

# 仮想環境の有効化（Windows）
# .venv\Scripts\activate

# 仮想環境の有効化（Mac/Linux）
# source .venv/bin/activate
