# %%
# 4. 数値を出力
print(3)

# %%
# 5. 四則演算など
print(3 + 7)
print(7 - 3)
print(3 * 7)  # 掛け算は「* (アスタリスク)」
print(3 / 2)  # 割り算は「/ (スラッシュ)」

print(7 % 3)  # 割り算の余りは「% (パーセント)」
print(16 // 3)  # 小数点以下の切り捨ては「// (ダブルスラッシュ)」

# %%
# 6. クオーテーションで囲むと...？
print('3 + 7')
